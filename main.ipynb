# %% [markdown]
# # Universal gpx parser

# %% [markdown]
# The aim of this project is quite basic: to create a standarized procedure that can parse a number of *gpx* files and output its contents as a **Pandas** Dataframe in a reasonable amount of time.

# %%
#Importing ur libraries.

import pandas as pd
import time
import re
import pathlib
import os
import gpxpy
import gpxpy.gpx
import time
from pathlib import Path
import os

# %% [markdown]
# ## Exploring different methods to store parsed gpx files

# %%
#Defining a function to parse our gpx files while retaining the valuable data.

def parser(file):
    try:
        gpx_file = open(file, 'r', encoding='utf-8') 
        gpx = gpxpy.parse(gpx_file) 
        coords = []
        alt = []
        for track in gpx.tracks:
            for segment in track.segments:        
                for point in segment.points:
                    coords.append(tuple([point.latitude, point.longitude]))
                    alt.append(point.elevation)
        parsed_file = {'name': track.name, 
                       'coords': [coords], 
                       'alt': [alt], 
                       'distance': track.length_3d()/1000, 
                       'climb': int(gpx.get_uphill_downhill()[0]),
                       'min_alt': int(gpx.get_elevation_extremes()[0]),
                       'max_alt': int(gpx.get_elevation_extremes()[1]),
                       's_la': coords[0][0],
                       's_lo': coords[0][1],
                       'f_la': coords[-1][0],
                       'f_lo': coords[-1][1],}
        df = pd.DataFrame(parsed_file)
        return df
    except:
        pass

# %%
start = time.time()

dict_list = []

directory = 'gpx'
 
files = Path(directory).glob('*')

counter = 0
for file in files:
    parser(file).to_csv(str(counter) + '.csv', index=False)
    counter += 1
    
stop = time.time() 
duration = (stop - start) / 60
print('Minutes:', duration)
# Out:
# Minutes: 16.18967688481013

# %%
df = pd.read_csv('54.csv')

# %%
df
# Out:
#        name                                             coords  \
# 0  竹滬旗山甲仙三民  [(22.85832, 120.22841), (22.85876, 120.22838),...
#
#                                                  alt   distance  climb  \
# 0  [11.0, 11.0, 11.0, 11.0, 12.0, 12.0, 12.0, 11....  97.744293   1778
#
#    min_alt  max_alt      s_la       s_lo      f_la       f_lo
# 0        6      714  22.85832  120.22841  23.27561  120.72025

# %%
#Creating a dataframe with the list of dictionaries.

df = pd.DataFrame(dict_list)

# %%
df.to_csv('df.csv', index=False)

# %%
df.head(50)
# Out:
#                                                  name  \
# 0                                        !. Mai Route
# 1                                        !. Mai Route
# 2                               !. Versuch mit Dieter
# 3                               !. Versuch mit Dieter
# 4   !3nádrže NMlýnů.. Nik-VNěm-Hust-Zaj-Mil-Pav-DV...
# 5   !3nádrže NMlýnů.. Nik-VNěm-Hust-Zaj-Mil-Pav-DV...
# 6                                                 !hg
# 7                                                 !hg
# 8                               # 13 Boucle du moulin
# 9                               # 13 Boucle du moulin
# 10                          # 17 La rivière Bécancour
# 11                          # 17 La rivière Bécancour
# 12                              # 4 Route panoramique
# 13                              # 4 Route panoramique
# 14                       # 5 La Route des antiquaires
# 15                       # 5 La Route des antiquaires
# 16                                 # Danix64 > Emko29
# 17                                 # Danix64 > Emko29
# 18                       # Časovka na Gretľu po ceste
# 19                       # Časovka na Gretľu po ceste
# 20                                                ###
# 21                                         ##########
# 22                                         ##########
# 23                                                ###
# 24                                               #001
# 25                                               #001
# 26                                               #002
# 27                                               #002
# 28                                   #1 - 21 VII 2009
# 29                                   #1 - 21 VII 2009
# 30                      #1 Bobiesgasse-Lorenzteich A2
# 31                      #1 Bobiesgasse-Lorenzteich A2
# 32                             #1 La Route des fleurs
# 33                             #1 La Route des fleurs
# 34                                            #1 M-ow
# 35                                            #1 M-ow
# 36                 #1 Śrem - Dols - Książ Wlkp - Śrem
# 37                 #1 Śrem - Dols - Książ Wlkp - Śrem
# 38                               #1, Extended Commute
# 39                               #1, Extended Commute
# 40                                  #10 - 3 VIII 2009
# 41                                  #10 - 3 VIII 2009
# 42                    #10 Route du Petit Deschaillons
# 43                    #10 Route du Petit Deschaillons
# 44                                  #11 - 4 VIII 2009
# 45                                  #11 - 4 VIII 2009
# 46                            #11 Boucle de la Plaine
# 47                            #11 Boucle de la Plaine
# 48                                  #12 - 6 VIII 2009
# 49                                  #12 - 6 VIII 2009
#
#                                                coords  \
# 0   [[(53.05482, 7.33192), (53.05385, 7.33212), (5...
# 1   [[(53.05482, 7.33192), (53.05385, 7.33212), (5...
# 2   [[(50.87778, 6.69063), (50.87723, 6.68634), (5...
# 3   [[(50.87778, 6.69063), (50.87723, 6.68634), (5...
# 4   [[(48.99251, 16.75447), (48.99248, 16.75414), ...
# 5   [[(48.99251, 16.75447), (48.99248, 16.75414), ...
# 6   [[(52.10393, 20.63397), (52.10457, 20.63537), ...
# 7   [[(52.10393, 20.63397), (52.10457, 20.63537), ...
# 8   [[(45.85329, -72.39056), (45.85237, -72.3889),...
# 9   [[(45.85329, -72.39056), (45.85237, -72.3889),...
# 10  [[(46.37204, -71.62193), (46.36304, -71.62854)...
# 11  [[(46.37204, -71.62193), (46.36304, -71.62854)...
# 12  [[(46.05596, -71.95895), (46.0565, -71.95861),...
# 13  [[(46.05596, -71.95895), (46.0565, -71.95861),...
# 14  [[(46.20084, -72.13717), (46.20092, -72.13679)...
# 15  [[(46.20084, -72.13717), (46.20092, -72.13679)...
# 16  [[(48.95545, 20.53853), (48.9543, 20.53821), (...
# 17  [[(48.95545, 20.53853), (48.9543, 20.53821), (...
# 18  [[(48.94375, 20.56181), (48.94316, 20.56109), ...
# 19  [[(48.94375, 20.56181), (48.94316, 20.56109), ...
# 20  [[(47.55302, 16.0864), (47.55279, 16.08665), (...
# 21  [[(54.47572, 9.86232), (54.47627, 9.86272), (5...
# 22  [[(54.47572, 9.86232), (54.47627, 9.86272), (5...
# 23  [[(47.55302, 16.0864), (47.55279, 16.08665), (...
# 24  [[(51.50291, 7.45443), (51.50264, 7.45369), (5...
# 25  [[(51.50291, 7.45443), (51.50264, 7.45369), (5...
# 26  [[(51.52338, 7.36917), (51.52477, 7.36929), (5...
# 27  [[(51.52338, 7.36917), (51.52477, 7.36929), (5...
# 28  [[(50.19229, 19.15981), (50.19223, 19.16106), ...
# 29  [[(50.19229, 19.15981), (50.19223, 19.16106), ...
# 30  [[(48.13806, 16.31802), (48.13753, 16.31801), ...
# 31  [[(48.13806, 16.31802), (48.13753, 16.31801), ...
# 32  [[(45.94974, -71.99735), (45.95045, -71.99802)...
# 33  [[(45.94974, -71.99735), (45.95045, -71.99802)...
# 34  [[(51.97398, 20.52475), (51.97411, 20.5208), (...
# 35  [[(51.97398, 20.52475), (51.97411, 20.5208), (...
# 36  [[(52.0803, 17.00769), (52.08056, 17.0072), (5...
# 37  [[(52.0803, 17.00769), (52.08056, 17.0072), (5...
# 38  [[(46.68127, -120.51779), (46.6869, -120.5174)...
# 39  [[(46.68127, -120.51779), (46.6869, -120.5174)...
# 40  [[(50.19222, 19.15975), (50.193, 19.16098), (5...
# 41  [[(50.19222, 19.15975), (50.193, 19.16098), (5...
# 42  [[(46.51884, -72.06378), (46.51218, -72.05446)...
# 43  [[(46.51884, -72.06378), (46.51218, -72.05446)...
# 44  [[(50.19227, 19.16011), (50.19157, 19.15968), ...
# 45  [[(50.19227, 19.16011), (50.19157, 19.15968), ...
# 46  [[(45.9418, -72.51949), (45.93863, -72.51629),...
# 47  [[(45.9418, -72.51949), (45.93863, -72.51629),...
# 48  [[(50.19158, 19.15943), (50.19157, 19.15975), ...
# 49  [[(50.19158, 19.15943), (50.19157, 19.15975), ...
#
#                                                   alt   distance  climb  \
# 0   [[4.0, 5.0, 5.0, 5.0, 4.0, 3.0, 3.0, 3.0, 3.0,...  50.670543     56
# 1   [[4.0, 5.0, 5.0, 5.0, 4.0, 3.0, 3.0, 3.0, 3.0,...  50.670543     56
# 2   [[84.0, 82.0, 85.0, 84.0, 83.0, 86.0, 87.0, 83...   2.885819      2
# 3   [[84.0, 82.0, 85.0, 84.0, 83.0, 86.0, 87.0, 83...   2.885819      2
# 4   [[265.0, 265.0, 265.0, 266.0, 252.0, 251.0, 25...  71.425151    454
# 5   [[265.0, 265.0, 265.0, 266.0, 252.0, 251.0, 25...  71.425151    454
# 6   [[104.0, 106.0, 106.0, 105.0, 105.0, 105.0, 10...  50.486244     99
# 7   [[104.0, 106.0, 106.0, 105.0, 105.0, 105.0, 10...  50.486244     99
# 8   [[104.0, 102.0, 101.0, 100.0, 101.0, 103.0, 10...  82.124462    368
# 9   [[104.0, 102.0, 101.0, 100.0, 101.0, 103.0, 10...  82.124462    368
# 10  [[137.0, 132.0, 132.0, 138.0, 140.0, 145.0, 14...  48.426866     74
# 11  [[137.0, 132.0, 132.0, 138.0, 140.0, 145.0, 14...  48.426866     74
# 12  [[131.0, 131.0, 131.0, 130.0, 132.0, 132.0, 13...  90.887461    938
# 13  [[131.0, 131.0, 131.0, 130.0, 132.0, 132.0, 13...  90.887461    938
# 14  [[89.0, 89.0, 92.0, 92.0, 92.0, 91.0, 89.0, 87...  70.664303    160
# 15  [[89.0, 89.0, 92.0, 92.0, 92.0, 91.0, 89.0, 87...  70.664303    160
# 16  [[474.0, 473.0, 473.0, 473.0, 472.0, 471.0, 47...   3.127121      1
